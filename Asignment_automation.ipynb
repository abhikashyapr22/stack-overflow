# %% [markdown]
# <a href="https://colab.research.google.com/github/abhikashyapr22/stack-overflow/blob/master/Asignment_automation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(data=[[1,1,'pass',"male"],
                             [2,1,'pass',"female"],
                             [3,2,'fail',"female"]],
                       columns=['ID', 'TEST_TYPE', 'TEST_STATUS','TEST_DATE'])

# %%
df
# Out:
#    ID  TEST_TYPE TEST_STATUS TEST_DATE
# 0   1          1        pass      male
# 1   2          1        pass    female
# 2   3          2        fail    female

# %%
df[df['TEST_STATUS']=='pass'].groupby('TEST_STATUS').count()
# Out:
#              ID  TEST_TYPE  TEST_DATE
# TEST_STATUS
# pass          2          2          2

# %%
d = {'list1':[1,3,4,5],
     'list2':[7,8,9,0],
     'list3':[5,6,7,8]}

# %%
df1 = pd.DataFrame(d)

# %%
df1
# Out:
#    list1  list2  list3
# 0      1      7      5
# 1      3      8      6
# 2      4      9      7
# 3      5      0      8

# %%
list1 = [1,3,4,5]
list2 = [7,8,9,0]
list3 = [5,6,7,8]

# %%
lists = [list1, list2, list3]

# %%
# final solution

d2 = {}
list_df =[]
lists = [list1, list2, list3]

for ind,l in enumerate(lists):
  #print(ind, l)
  if ind not in d2:
    d2[f'list_{ind}']=l
    list_df.append(pd.DataFrame(d2))

list_df[0]

# %%
d2
# Out:
# {'list_0': [1, 3, 4, 5], 'list_1': [7, 8, 9, 0], 'list_2': [5, 6, 7, 8]}

# %%
list_df[0]
# Out:
#    list_0
# 0       1
# 1       3
# 2       4
# 3       5

# %%
pd.DataFrame(d2)
# Out:
#    list_0  list_1  list_2
# 0       1       7       5
# 1       3       8       6
# 2       4       9       7
# 3       5       0       8

# %%
d2 = {}
list_df =[]
for l in lists:
  if l not in d2:
    d2[f'{l}']=l
    list_df.append(pd.DataFrame(d2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-ca405e815f75> in <module>()
#       4   if l not in d2:
#       5     d2[f'{l}']=l
# ----> 6     list_df.append(pd.DataFrame(d2))
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# ...
